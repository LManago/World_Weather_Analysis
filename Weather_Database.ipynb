# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Import the time module.
import time


# Import the API key.
from config import weather_api_key

# Import the API key.
from config import g_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Generate 1,500 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=1500)
lngs = np.random.uniform(-180.0,180.0,size=1500)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['rikitea', 'atuona', 'kapaa', 'bredasdorp', 'borger', 'kodiak', 'cape town', 'vaini', 'bluff', 'marcona'] Generate 631

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | borger
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 1 | codrington
# Processing Record 12 of Set 1 | clyde river
# Processing Record 13 of Set 1 | ponta do sol
# Processing Record 14 of Set 1 | severo-kurilsk
# Processing Record 15 of Set 1 | sitka
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | eyl
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | yershov
# Processing Record 21 of Set 1 | morondava
# Processing Record 22 of Set 1 | nakhon phanom
# Processing Record 23 of Set 1 | jacksonville beach
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | pisco
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | khunti
# Processing Record 31 of Set 1 | pathein
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | media luna
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | port-gentil
# Processing Record 36 of Set 1 | quatre cocos
# Processing Record 37 of Set 1 | vila
# Processing Record 38 of Set 1 | la sarre
# Processing Record 39 of Set 1 | morehead
# Processing Record 40 of Set 1 | sankt florian
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | isangel
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | vardo
# Processing Record 50 of Set 1 | hambantota
# Processing Record 1 of Set 2 | marv dasht
# City not found. Skipping...
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | fallon
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | san andres
# Processing Record 6 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | urucara
# Processing Record 9 of Set 2 | ligayan
# Processing Record 10 of Set 2 | suntar
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | green river
# Processing Record 13 of Set 2 | leningradskiy
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | bandarbeyla
# Processing Record 16 of Set 2 | sola
# Processing Record 17 of Set 2 | gat
# Processing Record 18 of Set 2 | saint anthony
# Processing Record 19 of Set 2 | souillac
# Processing Record 20 of Set 2 | comodoro rivadavia
# Processing Record 21 of Set 2 | amatlan
# City not found. Skipping...
# Processing Record 22 of Set 2 | brazzaville
# Processing Record 23 of Set 2 | jinsha
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 27 of Set 2 | morrelganj
# City not found. Skipping...
# Processing Record 28 of Set 2 | preston
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | los arcos
# Processing Record 31 of Set 2 | alzamay
# Processing Record 32 of Set 2 | qaqortoq
# Processing Record 33 of Set 2 | angoche
# Processing Record 34 of Set 2 | sabang
# Processing Record 35 of Set 2 | castelo do piaui
# Processing Record 36 of Set 2 | batemans bay
# Processing Record 37 of Set 2 | berlevag
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | buraydah
# Processing Record 40 of Set 2 | nanakuli
# Processing Record 41 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 2 | muros
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | salym
# Processing Record 45 of Set 2 | oktyabrskiy
# Processing Record 46 of Set 2 | pascagoula
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | cap-aux-meules
# Processing Record 1 of Set 3 | ketou
# Processing Record 2 of Set 3 | acapulco
# Processing Record 3 of Set 3 | teguise
# Processing Record 4 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 3 | mayor pablo lagerenza
# Processing Record 6 of Set 3 | ahipara
# Processing Record 7 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 3 | waingapu
# Processing Record 9 of Set 3 | carnarvon
# Processing Record 10 of Set 3 | paracuru
# Processing Record 11 of Set 3 | nizwa
# Processing Record 12 of Set 3 | acajutla
# Processing Record 13 of Set 3 | raga
# Processing Record 14 of Set 3 | borehamwood
# Processing Record 15 of Set 3 | anadyr
# Processing Record 16 of Set 3 | santa elena
# Processing Record 17 of Set 3 | bilma
# Processing Record 18 of Set 3 | leh
# Processing Record 19 of Set 3 | valledupar
# Processing Record 20 of Set 3 | lagoa
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | rovenki
# Processing Record 23 of Set 3 | abyek
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | salvador
# Processing Record 27 of Set 3 | kapoeta
# Processing Record 28 of Set 3 | folkestone
# Processing Record 29 of Set 3 | okhotsk
# Processing Record 30 of Set 3 | tuban
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | pivijay
# Processing Record 33 of Set 3 | guarapari
# Processing Record 34 of Set 3 | miri
# Processing Record 35 of Set 3 | zabaykalsk
# Processing Record 36 of Set 3 | victor harbor
# Processing Record 37 of Set 3 | alexander city
# Processing Record 38 of Set 3 | gizo
# Processing Record 39 of Set 3 | pacific grove
# Processing Record 40 of Set 3 | sungairaya
# Processing Record 41 of Set 3 | amqui
# Processing Record 42 of Set 3 | victoria
# Processing Record 43 of Set 3 | paita
# Processing Record 44 of Set 3 | santa maria
# Processing Record 45 of Set 3 | naze
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | la rioja
# Processing Record 48 of Set 3 | northam
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | husavik
# Processing Record 1 of Set 4 | quelimane
# Processing Record 2 of Set 4 | longyearbyen
# Processing Record 3 of Set 4 | hotarele
# Processing Record 4 of Set 4 | tripoli
# Processing Record 5 of Set 4 | prince rupert
# Processing Record 6 of Set 4 | tiznit
# Processing Record 7 of Set 4 | airai
# Processing Record 8 of Set 4 | kaabong
# Processing Record 9 of Set 4 | bonwapitse
# Processing Record 10 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | thompson
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | bethel
# Processing Record 14 of Set 4 | cobija
# Processing Record 15 of Set 4 | nikki
# Processing Record 16 of Set 4 | cherskiy
# Processing Record 17 of Set 4 | pulaski
# Processing Record 18 of Set 4 | banyo
# Processing Record 19 of Set 4 | atessa
# Processing Record 20 of Set 4 | rio gallegos
# Processing Record 21 of Set 4 | sinnamary
# Processing Record 22 of Set 4 | presidencia roque saenz pena
# Processing Record 23 of Set 4 | kruisfontein
# Processing Record 24 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 4 | polyarnyye zori
# Processing Record 26 of Set 4 | vila do maio
# Processing Record 27 of Set 4 | uruana
# Processing Record 28 of Set 4 | klaksvik
# Processing Record 29 of Set 4 | tual
# Processing Record 30 of Set 4 | bambous virieux
# Processing Record 31 of Set 4 | sao filipe
# Processing Record 32 of Set 4 | tuatapere
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | ambulu
# Processing Record 35 of Set 4 | jumla
# Processing Record 36 of Set 4 | talara
# Processing Record 37 of Set 4 | sorland
# Processing Record 38 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | dalvik
# Processing Record 41 of Set 4 | oranjestad
# Processing Record 42 of Set 4 | kutum
# Processing Record 43 of Set 4 | broken hill
# Processing Record 44 of Set 4 | lujiang
# Processing Record 45 of Set 4 | chifeng
# Processing Record 46 of Set 4 | cabedelo
# Processing Record 47 of Set 4 | sabalgarh
# Processing Record 48 of Set 4 | saint-louis
# Processing Record 49 of Set 4 | penzance
# Processing Record 50 of Set 4 | imbituba
# Processing Record 1 of Set 5 | caborca
# Processing Record 2 of Set 5 | mahebourg
# Processing Record 3 of Set 5 | ilulissat
# Processing Record 4 of Set 5 | qaanaaq
# Processing Record 5 of Set 5 | touros
# Processing Record 6 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 5 | guajara-mirim
# City not found. Skipping...
# Processing Record 8 of Set 5 | nome
# Processing Record 9 of Set 5 | chalons-en-champagne
# Processing Record 10 of Set 5 | trelaze
# Processing Record 11 of Set 5 | alekseyevsk
# Processing Record 12 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 5 | paso de carrasco
# Processing Record 14 of Set 5 | mar del plata
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | ribeira grande
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | the valley
# Processing Record 19 of Set 5 | jasper
# Processing Record 20 of Set 5 | port blair
# Processing Record 21 of Set 5 | kaeo
# Processing Record 22 of Set 5 | pangnirtung
# Processing Record 23 of Set 5 | rabo de peixe
# Processing Record 24 of Set 5 | athboy
# Processing Record 25 of Set 5 | rustenburg
# Processing Record 26 of Set 5 | ketchikan
# Processing Record 27 of Set 5 | sisimiut
# Processing Record 28 of Set 5 | beloha
# Processing Record 29 of Set 5 | horsham
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | cabo san lucas
# Processing Record 32 of Set 5 | port lincoln
# Processing Record 33 of Set 5 | nchelenge
# Processing Record 34 of Set 5 | mount gambier
# Processing Record 35 of Set 5 | vadso
# Processing Record 36 of Set 5 | palaikastron
# Processing Record 37 of Set 5 | puerto escondido
# Processing Record 38 of Set 5 | christchurch
# Processing Record 39 of Set 5 | taraza
# Processing Record 40 of Set 5 | marsa matruh
# Processing Record 41 of Set 5 | ouadda
# Processing Record 42 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 5 | kaitangata
# Processing Record 44 of Set 5 | ishigaki
# Processing Record 45 of Set 5 | marawi
# Processing Record 46 of Set 5 | margate
# Processing Record 47 of Set 5 | stornoway
# Processing Record 48 of Set 5 | kaili
# Processing Record 49 of Set 5 | khandyga
# Processing Record 50 of Set 5 | barcelos
# Processing Record 1 of Set 6 | novo oriente
# Processing Record 2 of Set 6 | hualmay
# Processing Record 3 of Set 6 | xining
# Processing Record 4 of Set 6 | maarianhamina
# Processing Record 5 of Set 6 | keuruu
# Processing Record 6 of Set 6 | baykit
# Processing Record 7 of Set 6 | yabrud
# Processing Record 8 of Set 6 | rawson
# Processing Record 9 of Set 6 | lebu
# Processing Record 10 of Set 6 | sao joao da barra
# Processing Record 11 of Set 6 | librazhd
# Processing Record 12 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 6 | yulara
# Processing Record 14 of Set 6 | pedernales
# Processing Record 15 of Set 6 | aklavik
# Processing Record 16 of Set 6 | chapais
# Processing Record 17 of Set 6 | vila velha
# Processing Record 18 of Set 6 | karakose
# City not found. Skipping...
# Processing Record 19 of Set 6 | bathsheba
# Processing Record 20 of Set 6 | bodden town
# Processing Record 21 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 6 | tevaitoa
# Processing Record 24 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 6 | kizner
# Processing Record 26 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 6 | ilebo
# Processing Record 28 of Set 6 | pochutla
# Processing Record 29 of Set 6 | ulaangom
# Processing Record 30 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 6 | richards bay
# Processing Record 32 of Set 6 | chokwe
# Processing Record 33 of Set 6 | iberia
# Processing Record 34 of Set 6 | dubbo
# Processing Record 35 of Set 6 | khatanga
# Processing Record 36 of Set 6 | maceio
# Processing Record 37 of Set 6 | iqaluit
# Processing Record 38 of Set 6 | filadelfia
# Processing Record 39 of Set 6 | torbay
# Processing Record 40 of Set 6 | lokosovo
# Processing Record 41 of Set 6 | fort-shevchenko
# Processing Record 42 of Set 6 | hirara
# Processing Record 43 of Set 6 | pastavy
# Processing Record 44 of Set 6 | kodinsk
# Processing Record 45 of Set 6 | avera
# Processing Record 46 of Set 6 | alvand
# Processing Record 47 of Set 6 | black diamond
# Processing Record 48 of Set 6 | nanortalik
# Processing Record 49 of Set 6 | benalla
# Processing Record 50 of Set 6 | xingcheng
# Processing Record 1 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 7 | taitung
# Processing Record 3 of Set 7 | mnogovershinnyy
# Processing Record 4 of Set 7 | troitsko-pechorsk
# Processing Record 5 of Set 7 | karasuk
# Processing Record 6 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 7 | othonoi
# City not found. Skipping...
# Processing Record 9 of Set 7 | lukang
# Processing Record 10 of Set 7 | santa isabel do rio negro
# Processing Record 11 of Set 7 | darnah
# Processing Record 12 of Set 7 | nianzishan
# Processing Record 13 of Set 7 | gravdal
# Processing Record 14 of Set 7 | georgetown
# Processing Record 15 of Set 7 | taltal
# Processing Record 16 of Set 7 | yeppoon
# Processing Record 17 of Set 7 | sur
# Processing Record 18 of Set 7 | myitkyina
# Processing Record 19 of Set 7 | egvekinot
# Processing Record 20 of Set 7 | boa vista
# Processing Record 21 of Set 7 | makakilo city
# Processing Record 22 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 7 | pevek
# Processing Record 24 of Set 7 | cap malheureux
# Processing Record 25 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 7 | tarakan
# Processing Record 27 of Set 7 | inuvik
# Processing Record 28 of Set 7 | oytal
# Processing Record 29 of Set 7 | vila franca do campo
# Processing Record 30 of Set 7 | flin flon
# Processing Record 31 of Set 7 | linqiong
# Processing Record 32 of Set 7 | port macquarie
# Processing Record 33 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 34 of Set 7 | kirakira
# Processing Record 35 of Set 7 | zaozerne
# Processing Record 36 of Set 7 | fortuna
# Processing Record 37 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 7 | mopipi
# Processing Record 39 of Set 7 | garowe
# Processing Record 40 of Set 7 | gigmoto
# Processing Record 41 of Set 7 | havelock
# Processing Record 42 of Set 7 | otukpo
# Processing Record 43 of Set 7 | tezpur
# Processing Record 44 of Set 7 | surt
# Processing Record 45 of Set 7 | general roca
# Processing Record 46 of Set 7 | kijang
# Processing Record 47 of Set 7 | ibra
# Processing Record 48 of Set 7 | talnakh
# Processing Record 49 of Set 7 | manitouwadge
# Processing Record 50 of Set 7 | idah
# Processing Record 1 of Set 8 | nishihara
# Processing Record 2 of Set 8 | tucuma
# Processing Record 3 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 8 | deputatskiy
# Processing Record 5 of Set 8 | ghatampur
# Processing Record 6 of Set 8 | kyra
# Processing Record 7 of Set 8 | norman wells
# Processing Record 8 of Set 8 | tabou
# Processing Record 9 of Set 8 | esna
# Processing Record 10 of Set 8 | sassandra
# Processing Record 11 of Set 8 | la cruz
# Processing Record 12 of Set 8 | shache
# Processing Record 13 of Set 8 | marzuq
# Processing Record 14 of Set 8 | olinda
# Processing Record 15 of Set 8 | port hedland
# Processing Record 16 of Set 8 | grand gaube
# Processing Record 17 of Set 8 | nichinan
# Processing Record 18 of Set 8 | bardiyah
# Processing Record 19 of Set 8 | forestville
# Processing Record 20 of Set 8 | westport
# Processing Record 21 of Set 8 | erenhot
# Processing Record 22 of Set 8 | lima
# Processing Record 23 of Set 8 | college
# Processing Record 24 of Set 8 | port hardy
# Processing Record 25 of Set 8 | taoudenni
# Processing Record 26 of Set 8 | el paso
# Processing Record 27 of Set 8 | salalah
# Processing Record 28 of Set 8 | truro
# Processing Record 29 of Set 8 | brindisi
# Processing Record 30 of Set 8 | faanui
# Processing Record 31 of Set 8 | san carlos de bariloche
# Processing Record 32 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 8 | saquarema
# Processing Record 34 of Set 8 | alofi
# Processing Record 35 of Set 8 | los llanos de aridane
# Processing Record 36 of Set 8 | ducheng
# Processing Record 37 of Set 8 | kornwestheim
# Processing Record 38 of Set 8 | russell
# Processing Record 39 of Set 8 | monte alegre
# Processing Record 40 of Set 8 | zlobin
# Processing Record 41 of Set 8 | batagay-alyta
# Processing Record 42 of Set 8 | bumba
# Processing Record 43 of Set 8 | alexandria
# Processing Record 44 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 8 | strezhevoy
# Processing Record 46 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 8 | walvis bay
# Processing Record 48 of Set 8 | kostomuksha
# Processing Record 49 of Set 8 | moses lake
# Processing Record 50 of Set 8 | vestmannaeyjar
# Processing Record 1 of Set 9 | kathu
# Processing Record 2 of Set 9 | yelovo
# Processing Record 3 of Set 9 | yar-sale
# Processing Record 4 of Set 9 | kasempa
# Processing Record 5 of Set 9 | san pedro
# Processing Record 6 of Set 9 | wattegama
# Processing Record 7 of Set 9 | antofagasta
# Processing Record 8 of Set 9 | san cristobal
# Processing Record 9 of Set 9 | san juan
# Processing Record 10 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 9 | villarrobledo
# Processing Record 12 of Set 9 | bengkulu
# Processing Record 13 of Set 9 | srednekolymsk
# Processing Record 14 of Set 9 | grosseto
# Processing Record 15 of Set 9 | geraldton
# Processing Record 16 of Set 9 | gidam
# Processing Record 17 of Set 9 | constitucion
# Processing Record 18 of Set 9 | fort nelson
# Processing Record 19 of Set 9 | marilia
# Processing Record 20 of Set 9 | karratha
# Processing Record 21 of Set 9 | lavrentiya
# Processing Record 22 of Set 9 | poum
# Processing Record 23 of Set 9 | kamaishi
# Processing Record 24 of Set 9 | buchanan
# Processing Record 25 of Set 9 | henties bay
# Processing Record 26 of Set 9 | padang
# Processing Record 27 of Set 9 | kerema
# Processing Record 28 of Set 9 | ust-uda
# Processing Record 29 of Set 9 | raghunathpur
# Processing Record 30 of Set 9 | narasannapeta
# Processing Record 31 of Set 9 | kholodnyy
# Processing Record 32 of Set 9 | gokak
# Processing Record 33 of Set 9 | valdosta
# Processing Record 34 of Set 9 | azare
# Processing Record 35 of Set 9 | kolosovka
# Processing Record 36 of Set 9 | gold coast
# Processing Record 37 of Set 9 | kemin
# Processing Record 38 of Set 9 | vagur
# Processing Record 39 of Set 9 | eha amufu
# Processing Record 40 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 9 | baillif
# Processing Record 42 of Set 9 | khoy
# Processing Record 43 of Set 9 | ati
# Processing Record 44 of Set 9 | riyadh
# Processing Record 45 of Set 9 | ancud
# Processing Record 46 of Set 9 | georgiyevskoye
# Processing Record 47 of Set 9 | dicabisagan
# Processing Record 48 of Set 9 | mingaora
# Processing Record 49 of Set 9 | axim
# Processing Record 50 of Set 9 | jaca
# Processing Record 1 of Set 10 | tahta
# Processing Record 2 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 10 | hueytamalco
# Processing Record 4 of Set 10 | solnechnyy
# Processing Record 5 of Set 10 | san-pedro
# Processing Record 6 of Set 10 | keelung
# Processing Record 7 of Set 10 | north bend
# Processing Record 8 of Set 10 | lipin bor
# Processing Record 9 of Set 10 | singaraja
# Processing Record 10 of Set 10 | massakory
# Processing Record 11 of Set 10 | port moresby
# Processing Record 12 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 10 | elko
# Processing Record 14 of Set 10 | portland
# Processing Record 15 of Set 10 | kupang
# Processing Record 16 of Set 10 | manaus
# Processing Record 17 of Set 10 | puerto leguizamo
# Processing Record 18 of Set 10 | mimoso do sul
# Processing Record 19 of Set 10 | steamboat springs
# Processing Record 20 of Set 10 | ust-kuyga
# Processing Record 21 of Set 10 | odweyne
# Processing Record 22 of Set 10 | evensk
# Processing Record 23 of Set 10 | ngerengere
# Processing Record 24 of Set 10 | samarai
# Processing Record 25 of Set 10 | viedma
# Processing Record 26 of Set 10 | clinton
# Processing Record 27 of Set 10 | aykhal
# Processing Record 28 of Set 10 | kotka
# Processing Record 29 of Set 10 | raudeberg
# Processing Record 30 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 31 of Set 10 | la ronge
# Processing Record 32 of Set 10 | hay river
# Processing Record 33 of Set 10 | micheweni
# Processing Record 34 of Set 10 | teahupoo
# Processing Record 35 of Set 10 | mackay
# Processing Record 36 of Set 10 | coffeyville
# Processing Record 37 of Set 10 | kenai
# Processing Record 38 of Set 10 | zomba
# Processing Record 39 of Set 10 | marsh harbour
# Processing Record 40 of Set 10 | puerto colombia
# Processing Record 41 of Set 10 | wakkanai
# Processing Record 42 of Set 10 | tazovskiy
# Processing Record 43 of Set 10 | dunedin
# Processing Record 44 of Set 10 | derzhavinsk
# Processing Record 45 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 46 of Set 10 | vermillion
# Processing Record 47 of Set 10 | kahului
# Processing Record 48 of Set 10 | suphan buri
# Processing Record 49 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 50 of Set 10 | marienburg
# Processing Record 1 of Set 11 | saint-francois
# Processing Record 2 of Set 11 | caravelas
# Processing Record 3 of Set 11 | panguna
# Processing Record 4 of Set 11 | astoria
# Processing Record 5 of Set 11 | superior
# Processing Record 6 of Set 11 | zhicheng
# Processing Record 7 of Set 11 | dingle
# Processing Record 8 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 9 of Set 11 | zhangye
# Processing Record 10 of Set 11 | rock sound
# Processing Record 11 of Set 11 | long beach
# Processing Record 12 of Set 11 | sulangan
# Processing Record 13 of Set 11 | roald
# Processing Record 14 of Set 11 | dosso
# Processing Record 15 of Set 11 | uyuni
# Processing Record 16 of Set 11 | anloga
# Processing Record 17 of Set 11 | camana
# Processing Record 18 of Set 11 | hovd
# Processing Record 19 of Set 11 | verkhnevilyuysk
# Processing Record 20 of Set 11 | benguela
# Processing Record 21 of Set 11 | fairview
# Processing Record 22 of Set 11 | vanavara
# Processing Record 23 of Set 11 | cody
# Processing Record 24 of Set 11 | meulaboh
# Processing Record 25 of Set 11 | palmer
# Processing Record 26 of Set 11 | general pico
# Processing Record 27 of Set 11 | gairo
# Processing Record 28 of Set 11 | luderitz
# Processing Record 29 of Set 11 | shkoder
# Processing Record 30 of Set 11 | nantucket
# Processing Record 31 of Set 11 | pansemal
# Processing Record 32 of Set 11 | kongsberg
# Processing Record 33 of Set 11 | mount isa
# Processing Record 34 of Set 11 | alta floresta
# Processing Record 35 of Set 11 | hasaki
# Processing Record 36 of Set 11 | waddan
# Processing Record 37 of Set 11 | calabar
# Processing Record 38 of Set 11 | labuhan
# Processing Record 39 of Set 11 | pasni
# Processing Record 40 of Set 11 | hamilton
# Processing Record 41 of Set 11 | banda aceh
# Processing Record 42 of Set 11 | namibe
# Processing Record 43 of Set 11 | thomasville
# Processing Record 44 of Set 11 | saint-pierre
# Processing Record 45 of Set 11 | copparo
# Processing Record 46 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 11 | bambanglipuro
# Processing Record 48 of Set 11 | kroya
# Processing Record 49 of Set 11 | cayenne
# Processing Record 50 of Set 11 | zhezkazgan
# Processing Record 1 of Set 12 | yumen
# Processing Record 2 of Set 12 | eureka
# Processing Record 3 of Set 12 | elwood
# Processing Record 4 of Set 12 | malartic
# Processing Record 5 of Set 12 | paamiut
# Processing Record 6 of Set 12 | bonavista
# Processing Record 7 of Set 12 | havoysund
# Processing Record 8 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 9 of Set 12 | miguel hidalgo
# Processing Record 10 of Set 12 | palkaka
# City not found. Skipping...
# Processing Record 11 of Set 12 | le passage
# Processing Record 12 of Set 12 | harper
# Processing Record 13 of Set 12 | ulladulla
# Processing Record 14 of Set 12 | bilibino
# Processing Record 15 of Set 12 | trelleborg
# Processing Record 16 of Set 12 | krasnoselkup
# Processing Record 17 of Set 12 | baracoa
# Processing Record 18 of Set 12 | nizhnevartovsk
# Processing Record 19 of Set 12 | durham
# Processing Record 20 of Set 12 | guerrero negro
# Processing Record 21 of Set 12 | bam
# Processing Record 22 of Set 12 | burnie
# Processing Record 23 of Set 12 | kilindoni
# Processing Record 24 of Set 12 | adrar
# Processing Record 25 of Set 12 | laguna
# Processing Record 26 of Set 12 | caucaia
# Processing Record 27 of Set 12 | mangrol
# Processing Record 28 of Set 12 | buta
# Processing Record 29 of Set 12 | sarkand
# Processing Record 30 of Set 12 | yaan
# Processing Record 31 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 12 | tessalit
# Processing Record 33 of Set 12 | yuli
# Processing Record 34 of Set 12 | tahlequah
# Processing Record 35 of Set 12 | khor
# Processing Record 36 of Set 12 | atar
# Processing Record 37 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 38 of Set 12 | chlorakas
# Processing Record 39 of Set 12 | smolenka
# Processing Record 40 of Set 12 | san quintin
# Processing Record 41 of Set 12 | dhule
# Processing Record 42 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 12 | takoradi
# Processing Record 44 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 12 | tiarei
# Processing Record 46 of Set 12 | hofn
# Processing Record 47 of Set 12 | vao
# Processing Record 48 of Set 12 | lata
# Processing Record 49 of Set 12 | ankara
# Processing Record 50 of Set 12 | shitkino
# Processing Record 1 of Set 13 | les escoumins
# Processing Record 2 of Set 13 | broome
# Processing Record 3 of Set 13 | zapolyarnyy
# Processing Record 4 of Set 13 | bandar maharani
# City not found. Skipping...
# Processing Record 5 of Set 13 | waipawa
# Processing Record 6 of Set 13 | cape elizabeth
# City not found. Skipping...
# Processing Record 7 of Set 13 | santo antonio do ica
# Processing Record 8 of Set 13 | ukiah
# Processing Record 9 of Set 13 | cockburn town
# Processing Record 10 of Set 13 | asau
# Processing Record 11 of Set 13 | oregon
# Processing Record 12 of Set 13 | katsuura
# Processing Record 13 of Set 13 | montepuez
# Processing Record 14 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 15 of Set 13 | silver city
# Processing Record 16 of Set 13 | shar
# Processing Record 17 of Set 13 | ziro
# Processing Record 18 of Set 13 | novyy urengoy
# Processing Record 19 of Set 13 | penarroya-pueblonuevo
# Processing Record 20 of Set 13 | seoul
# Processing Record 21 of Set 13 | aksum
# Processing Record 22 of Set 13 | jubayl
# City not found. Skipping...
# Processing Record 23 of Set 13 | tanabe
# Processing Record 24 of Set 13 | loei
# Processing Record 25 of Set 13 | edson
# Processing Record 26 of Set 13 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 27 of Set 13 | batticaloa
# Processing Record 28 of Set 13 | sept-iles
# Processing Record 29 of Set 13 | shiraz
# Processing Record 30 of Set 13 | qiyang
# Processing Record 31 of Set 13 | kloulklubed
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 573

# %%
#Save the new DataFrame as a CSV file
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.to_csv(path_or_buf='C:/Users/Lakenia/Desktop/World_Weather_Analysis/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv', index_label='City_ID')

# %%
challenge_city_data_df
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        rikitea      PF -23.12 -134.97     74.46        86          86
# 1         atuona      PF  -9.80 -139.03     77.41        80          28
# 2          kapaa      US  22.08 -159.32     82.40        74           1
# 3     bredasdorp      ZA -34.53   20.04     64.40        88          39
# 4         borger      NL  52.92    6.79     62.01        93          98
# ..           ...     ...    ...     ...       ...       ...         ...
# 568   batticaloa      LK   7.71   81.69     80.24        76          51
# 569    sept-iles      CA  50.20  -66.38     37.40        59         100
# 570       shiraz      IR  29.60   52.54     51.80        27           0
# 571       qiyang      CN  26.59  111.85     59.65        73         100
# 572  kloulklubed      PW   7.04  134.26     75.20       100          75
#
#      Wind Speed Current Description
# 0         21.72          light rain
# 1         14.34          light rain
# 2          5.82           clear sky
# 3          8.05    scattered clouds
# 4         11.01     overcast clouds
# ..          ...                 ...
# 568        7.07       broken clouds
# 569        4.70     overcast clouds
# 570        4.70           clear sky
# 571        0.67     overcast clouds
# 572        6.42       broken clouds
#
# [573 rows x 9 columns]
